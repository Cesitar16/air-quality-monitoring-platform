# %% [markdown]
# # ETL exploracion
#
# Notebook de apoyo para revisar entradas raw, salidas procesadas y validaciones del pipeline ETL.

# %%
from pathlib import Path
import pandas as pd

root = Path.cwd().parents[1] if Path.cwd().name == 'notebooks' else Path.cwd()
dataset = pd.read_csv(root / 'data' / 'processed' / 'dataset_modelado.csv')
dataset.head()
# Out:
#             fecha_hora codigo_estacion    comuna     region  mp25  mp10   so2  \
# 0  2026-01-06 00:00:00      OF-RAN-001  Rancagua  O'Higgins  52.4  88.1  17.3
# 1  2026-01-06 06:00:00      OF-RAN-001  Rancagua  O'Higgins  49.8  84.4  16.8
# 2  2026-01-06 12:00:00      OF-RAN-001  Rancagua  O'Higgins  28.5  54.2  14.1
# 3  2026-01-06 18:00:00      OF-RAN-001  Rancagua  O'Higgins  45.2  76.3  15.9
# 4  2026-02-06 00:00:00      OF-TAL-001     Talca      Maule  61.7  97.5  13.6
#
#     no2  velocidad_viento  direccion_viento_grados  temperatura  humedad  \
# 0  31.0               1.2                    180.0          6.1     88.0
# 1  29.6               1.5                    195.0          5.2     91.0
# 2  24.7               4.6                    220.0         13.4     61.0
# 3  28.3               2.8                    205.0          9.3     74.0
# 4  27.4               1.0                    170.0          4.8     92.0
#
#   fuente_dato
# 0     oficial
# 1     oficial
# ...
